# %%
import cv2
import numpy as np

# 웹캠 신호 받기
VideoSignal = cv2.VideoCapture(0)

# img = cv2.imread('darknet/data/train.jpeg')

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov2-tiny.weights","yolov2-tiny.cfg")

# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i - 1] for i in YOLO_net.getUnconnectedOutLayers()]

while True:
    # 웹캠 프레임
    ret, frame = VideoSignal.read()
    h, w, c = frame.shape

    # YOLO 입력
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0),
    True, crop=False)
    YOLO_net.setInput(blob)
    outs = YOLO_net.forward(output_layers)

    class_ids = []
    confidences = []
    boxes = []

    #outs는 탐지한 물체의 수.
    for out in outs:

        for detection in out:

            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.5:
                # Object detected
                center_x = int(detection[0] * w)
                center_y = int(detection[1] * h)
                dw = int(detection[2] * w)
                dh = int(detection[3] * h)
                # Rectangle coordinate
                x = int(center_x - dw / 2)
                y = int(center_y - dh / 2)
                boxes.append([x, y, dw, dh])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.45, 0.4)


    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            score = confidences[i]

            # 경계상자와 클래스 정보 이미지에 입력
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 5)
            cv2.putText(frame, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, 
            (255, 255, 255), 1)

    cv2.imshow("YOLOv3", frame)

    c = cv2.waitKey(100)
    if c is not None and c & 0xFF == ord('q'):
        break

VideoSignal.release()
cv2.destroyAllWindows()

for i in range(1,5):
    cv2.waitKey(1)

# %% [markdown]
# # 이미지에 YOLO 씌워보기

# %%
import cv2
import numpy as np

img = cv2.imread('darknet/data/train.jpeg')
# target_img = img.copy() #사본 이미지

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov2-tiny.weights","yolov2-tiny.cfg")

# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i - 1] for i in YOLO_net.getUnconnectedOutLayers()]

h, w, c = img.shape

# YOLO 입력
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
YOLO_net.setInput(blob)
outs = YOLO_net.forward(output_layers)

class_ids = []
confidences = []
boxes = []

#outs가 감자한 갯수.
for out in outs:
    for detection in out:

        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]

        if confidence > 0.5:
            # Object detected
            center_x = int(detection[0] * w)
            center_y = int(detection[1] * h)
            dw = int(detection[2] * w)
            dh = int(detection[3] * h)
            # Rectangle coordinate
            x = int(center_x - dw / 2)
            y = int(center_y - dh / 2)
            boxes.append([x, y, dw, dh])
            confidences.append(float(confidence))
            class_ids.append(class_id)

indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.45, 0.4)

for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        score = confidences[i]

        # 경계상자와 클래스 정보 이미지에 입력
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 5)
        cv2.putText(img, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, (255, 255, 255), 1)

cv2.imshow("YOLOv3", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

for i in range(1,5):
    cv2.waitKey(1)

# %% [markdown]
# # 끊어서 확인해보기.

# %%
import cv2
import numpy as np

img = cv2.imread('darknet/data/train.jpeg')
# target_img = img.copy() #사본 이미지

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov2-tiny.weights","yolov2-tiny.cfg")

# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i - 1] for i in YOLO_net.getUnconnectedOutLayers()]

h, w, c = img.shape

# YOLO 입력
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
YOLO_net.setInput(blob)
outs = YOLO_net.forward(output_layers)

class_ids = []
confidences = []
boxes = []

# %%
outs
# Out:
# (array([[0.03923281, 0.03838501, 0.07154942, ..., 0.        , 0.        ,
#          0.        ],
#         [0.059252  , 0.04903477, 0.16103   , ..., 0.        , 0.        ,
#          0.        ],
#         [0.04941006, 0.03993195, 0.15757853, ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [0.95369965, 0.94204277, 0.12946333, ..., 0.        , 0.        ,
#          0.        ],
#         [0.96040416, 0.9546102 , 0.63166803, ..., 0.        , 0.        ,
#          0.        ],
#         [0.962107  , 0.954121  , 0.77699786, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),)

# %%
for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        score = confidences[i]

        # 경계상자와 클래스 정보 이미지에 입력
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 5)
        cv2.putText(img, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, (255, 255, 255), 1)

cv2.imshow("YOLOv3", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

for i in range(1,5):
    cv2.waitKey(1)

# %% [markdown]
# # YOLO v3 -tiny

# %%
import cv2
import numpy as np

img = cv2.imread('darknet/data/train.jpeg')
# target_img = img.copy() #사본 이미지

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov3-tiny.weights","yolov3-tiny.cfg")

# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i - 1] for i in YOLO_net.getUnconnectedOutLayers()]

h, w, c = img.shape

# YOLO 입력
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
YOLO_net.setInput(blob)
outs = YOLO_net.forward(output_layers)

class_ids = []
confidences = []
boxes = []

#outs가 감자한 갯수.
for out in outs:
    for detection in out:

        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]

        if confidence > 0.5:
            # Object detected
            center_x = int(detection[0] * w)
            center_y = int(detection[1] * h)
            dw = int(detection[2] * w)
            dh = int(detection[3] * h)
            # Rectangle coordinate
            x = int(center_x - dw / 2)
            y = int(center_y - dh / 2)
            boxes.append([x, y, dw, dh])
            confidences.append(float(confidence))
            class_ids.append(class_id)

indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.45, 0.4)

for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        score = confidences[i]

        # 경계상자와 클래스 정보 이미지에 입력
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 5)
        cv2.putText(img, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, (255, 255, 255), 1)

cv2.imshow("YOLOv3", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

for i in range(1,5):
    cv2.waitKey(1)

# %%
import cv2
import numpy as np

# 웹캠 신호 받기
VideoSignal = cv2.VideoCapture(0)

# img = cv2.imread('darknet/data/train.jpeg')
# target_img = img.copy() #사본 이미지

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov3.weights","yolov3.cfg")

# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i - 1] for i in YOLO_net.getUnconnectedOutLayers()]

while True:
    # 웹캠 프레임
    ret, frame = VideoSignal.read()
    h, w, c = frame.shape

    # YOLO 입력
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0),
    True, crop=False)
    YOLO_net.setInput(blob)
    outs = YOLO_net.forward(output_layers)

    class_ids = []
    confidences = []
    boxes = []

    for out in outs:

        for detection in out:

            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.5:
                # Object detected
                center_x = int(detection[0] * w)
                center_y = int(detection[1] * h)
                dw = int(detection[2] * w)
                dh = int(detection[3] * h)
                # Rectangle coordinate
                x = int(center_x - dw / 2)
                y = int(center_y - dh / 2)
                boxes.append([x, y, dw, dh])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.45, 0.4)


    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            score = confidences[i]

            # 경계상자와 클래스 정보 이미지에 입력
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 5)
            cv2.putText(frame, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, 
            (255, 255, 255), 1)

    cv2.imshow("YOLOv3", frame)

    c = cv2.waitKey(100)
    if c is not None and c & 0xFF == ord('q'):
        break

VideoSignal.release()
cv2.destroyAllWindows()

for i in range(1,5):
    cv2.waitKey(1)

# %% [markdown]
# # Yolo v3

# %%
import cv2
import numpy as np

# 웹캠 신호 받기
VideoSignal = cv2.VideoCapture(0)

# img = cv2.imread('darknet/data/train.jpeg')
# target_img = img.copy() #사본 이미지

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov3.weights","yolov3.cfg")

# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i - 1] for i in YOLO_net.getUnconnectedOutLayers()]

while True:
    # 웹캠 프레임
    ret, frame = VideoSignal.read()
    h, w, c = frame.shape

    # YOLO 입력
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0),
    True, crop=False)
    YOLO_net.setInput(blob)
    outs = YOLO_net.forward(output_layers)

    class_ids = []
    confidences = []
    boxes = []

    for out in outs:

        for detection in out:

            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.5:
                # Object detected
                center_x = int(detection[0] * w)
                center_y = int(detection[1] * h)
                dw = int(detection[2] * w)
                dh = int(detection[3] * h)
                # Rectangle coordinate
                x = int(center_x - dw / 2)
                y = int(center_y - dh / 2)
                boxes.append([x, y, dw, dh])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.45, 0.4)


    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            score = confidences[i]

            # 경계상자와 클래스 정보 이미지에 입력
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 5)
            cv2.putText(frame, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, 
            (255, 255, 255), 1)

    cv2.imshow("YOLOv3", frame)

    c = cv2.waitKey(100)
    if c is not None and c & 0xFF == ord('q'):
        break

VideoSignal.release()
cv2.destroyAllWindows()

for i in range(1,5):
    cv2.waitKey(1)

# %%
import cv2
import numpy as np

img = cv2.imread('darknet/data/train.jpeg')
# target_img = img.copy() #사본 이미지

# YOLO 가중치 파일과 CFG 파일 로드
YOLO_net = cv2.dnn.readNet("yolov3.weights","yolov3.cfg")

# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i - 1] for i in YOLO_net.getUnconnectedOutLayers()]

h, w, c = img.shape

# YOLO 입력
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
YOLO_net.setInput(blob)
outs = YOLO_net.forward(output_layers)

class_ids = []
confidences = []
boxes = []

#outs가 감자한 갯수.
for out in outs:
    for detection in out:

        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]

        if confidence > 0.5:
            # Object detected
            center_x = int(detection[0] * w)
            center_y = int(detection[1] * h)
            dw = int(detection[2] * w)
            dh = int(detection[3] * h)
            # Rectangle coordinate
            x = int(center_x - dw / 2)
            y = int(center_y - dh / 2)
            boxes.append([x, y, dw, dh])
            confidences.append(float(confidence))
            class_ids.append(class_id)

indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.45, 0.4)

for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        score = confidences[i]

        # 경계상자와 클래스 정보 이미지에 입력
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 5)
        cv2.putText(img, label, (x, y - 20), cv2.FONT_ITALIC, 0.5, (255, 255, 255), 1)

cv2.imshow("YOLOv3", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

for i in range(1,5):
    cv2.waitKey(1)

# %%
# YOLO NETWORK 재구성
classes = []
with open("yolo.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = YOLO_net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in YOLO_net.getUnconnectedOutLayers()]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hp/zz_v74bx3912w8s2fz07537r0000gn/T/ipykernel_44613/1261261016.py in <module>
#       4     classes = [line.strip() for line in f.readlines()]
#       5 layer_names = YOLO_net.getLayerNames()
# ----> 6 output_layers = [layer_names[i[0] - 1] for i in YOLO_net.getUnconnectedOutLayers()]
#
# /var/folders/hp/zz_v74bx3912w8s2fz07537r0000gn/T/ipykernel_44613/1261261016.py in <listcomp>(.0)
#       4     classes = [line.strip() for line in f.readlines()]
#       5 layer_names = YOLO_net.getLayerNames()
# ----> 6 output_layers = [layer_names[i[0] - 1] for i in YOLO_net.getUnconnectedOutLayers()]
#
# IndexError: invalid index to scalar variable.

# %%
YOLO_net.getUnconnectedOutLayers()
# Out:
# array([33], dtype=int32)

# %%
output_layers = [layer_names[i[0] - 1] for i in YOLO_net.getUnconnectedOutLayers()]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hp/zz_v74bx3912w8s2fz07537r0000gn/T/ipykernel_44613/4184322042.py in <module>
# ----> 1 output_layers = [layer_names[i[0] - 1] for i in YOLO_net.getUnconnectedOutLayers()]
#
# /var/folders/hp/zz_v74bx3912w8s2fz07537r0000gn/T/ipykernel_44613/4184322042.py in <listcomp>(.0)
# ----> 1 output_layers = [layer_names[i[0] - 1] for i in YOLO_net.getUnconnectedOutLayers()]
#
# IndexError: invalid index to scalar variable.

# %%
str = [for i in YOLO_net.getUnconnectedOutLayers()]
# Out:
#   File "/var/folders/hp/zz_v74bx3912w8s2fz07537r0000gn/T/ipykernel_44613/2115044969.py", line 1
#     str = [for i in YOLO_net.getUnconnectedOutLayers()]
#            ^
# SyntaxError: invalid syntax

# %%
for i in YOLO_net.getUnconnectedOutLayers():
    print(i)
# Out:
# 33

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")
classes = []
with open("coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = net.getLayerNames()
output_layers = [layer_names[i[ - 1] for i in net.getUnconnectedOutLayers()]
colors = np.random.uniform(0, 255, size=(len(classes), 3))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hp/zz_v74bx3912w8s2fz07537r0000gn/T/ipykernel_45572/3658138518.py in <module>
#       4     classes = [line.strip() for line in f.readlines()]
#       5 layer_names = net.getLayerNames()
# ----> 6 output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
#       7 colors = np.random.uniform(0, 255, size=(len(classes), 3))
#
# /var/folders/hp/zz_v74bx3912w8s2fz07537r0000gn/T/ipykernel_45572/3658138518.py in <listcomp>(.0)
#       4     classes = [line.strip() for line in f.readlines()]
#       5 layer_names = net.getLayerNames()
# ----> 6 output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
#       7 colors = np.random.uniform(0, 255, size=(len(classes), 3))
#
# IndexError: invalid index to scalar variable.
